# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
load_dotenv()

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.0)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", '''
        Want assistance provided by qualified individuals enabled with experience on understanding charts using technical analysis tools while interpreting macroeconomic environment prevailing across world consequently assisting customers acquire long term advantages requires clear verdicts thereforeseeking same through informed predictions written down precisely! Firststatement contains following content- “Can you tell us what future stock marketlooks like based upon current conditions?"
        '''),
        ("user", "{company} 주식에 투자해도 될까요? 마크다운형식으로 투자 보고서를 한글로 작성해 주세요.")
    ]
)

# %%
from langchain_core.output_parsers import StrOutputParser
chain = prompt | llm | StrOutputParser()
result = chain.invoke({"company": "삼성전자"})
print(result)
# Out:
# # 삼성전자 투자 보고서
#
# ## 1. 회사 개요
# 삼성전자는 전 세계에서 가장 큰 전자제품 제조업체 중 하나로, 반도체, 스마트폰, 가전제품 등 다양한 분야에서 활동하고 있습니다. 회사는 지속적인 기술 혁신과 글로벌 시장에서의 강력한 입지를 바탕으로 성장해왔습니다.
#
# ## 2. 현재 시장 상황
# ### 2.1. 글로벌 경제
# - **금리 인상**: 주요 국가들의 금리 인상이 지속되고 있어, 자금 조달 비용이 증가하고 있습니다.
# - **인플레이션**: 전 세계적으로 인플레이션 압력이 높아지고 있으며, 이는 소비자 지출에 영향을 미칠 수 있습니다.
#
# ### 2.2. 반도체 시장
# - **수요 증가**: AI, IoT, 5G 등 기술 발전으로 반도체 수요가 증가하고 있습니다.
# - **공급망 문제**: 여전히 공급망 문제가 존재하지만, 삼성전자는 이를 해결하기 위한 노력을 기울이고 있습니다.
#
# ## 3. 삼성전자의 재무 상태
# - **매출 성장**: 최근 몇 년간 매출이 지속적으로 성장하고 있으며, 특히 반도체 부문에서 강력한 실적을 보이고 있습니다.
# - **부채 비율**: 안정적인 부채 비율을 유지하고 있어 재무 건전성이 높습니다.
#
# ## 4. 기술적 분석
# - **주가 추세**: 최근 주가는 상승세를 보이고 있으며, 주요 지지선과 저항선을 분석할 필요가 있습니다.
# - **지표 분석**: RSI, MACD 등 기술적 지표를 통해 매수/매도 신호를 확인할 수 있습니다.
#
# ## 5. 투자 결론
# 삼성전자는 강력한 재무 상태와 성장 가능성을 가지고 있으며, 반도체 시장의 수요 증가로 인해 긍정적인 전망을 가지고 있습니다. 그러나 글로벌 경제의 불확실성과 금리 인상 등의 리스크를 고려해야 합니다.
#
# ### **투자 권장**
# - **매수**: 장기적인 관점에서 삼성전자 주식에 투자하는 것이 유망할 것으로 보입니다. 다만, 단기적인 변동성에 유의해야 합니다.
#
# ## 6. 리스크 요인
# - **글로벌 경제 불확실성**: 금리 인상 및 인플레이션 등 외부 요인에 따른 리스크.
# - **경쟁 심화**: 글로벌 경쟁업체들과의 경쟁이 심화되고 있습니다.
#
# ## 7. 결론
# 삼성전자는 기술력과 시장 점유율을 바탕으로 장기적인 성장 가능성이 높습니다. 따라서, 현재의 시장 상황을 고려할 때, 삼성전자 주식에 대한 투자는 긍정적으로 평가됩니다.
#
# ---
#
# 이 보고서는 투자 결정을 위한 참고 자료일 뿐이며, 개인의 투자 성향과 상황에 따라 신중한 판단이 필요합니다.

# %%
# 하지만 gpt가 갖고 있는 것은 옛날 자료이므로, 최근의 정보를 가져와 반영해야 함
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\treze\miniconda3\envs\llm\lib\site-packages (0.2.61)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (2.2.4)
# Requirement already satisfied: requests>=2.31 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: pycparser in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from requests>=2.31->yfinance) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

company = yf.Ticker("005930.KS")
company.info
# Out:
# {'address1': '129 Samsung-Ro',
#  'address2': 'Maetan-3dong Yeongtong-gu',
#  'city': 'Suwon',
#  'country': 'South Korea',
#  'website': 'https://www.samsung.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Samsung Electronics Co., Ltd. engages in the consumer electronics, information technology and mobile communications, device solutions businesses, and R&D Centers worldwide. It operates in four divisions such as DX, DS, SDC and Harman. The company offers smartphones, tablets, audio sounds, watches, switches, and accessories; TVs, and sound devices; appliances, including refrigerators, washing machines and dryers, vacuum cleaners, cooking appliances, dishwashers, air conditioners, and air purifiers; monitors and memory storage products; displays, and smart and LED signages; and other accessories. It also engages in venture capital investments, cloud services, network devices installation, semiconductor equipment services, digital advertising platforms, marketing, consulting, connected services provider, logistics, financing, and software design activities; toll processing and sales of semiconductors and display panels; development and sale of network solutions; manufacture of semiconductors and food; provision of repair services for electronic devices; and development and supply of semiconductor process defect and quality control software, as well as digital televisions, foundry, system large scale integration LSI, connected car systems, audio and visual products, enterprise automation solutions, and connected services. The company was incorporated in 1969 and is based in Suwon, South Korea.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Tae-Moon  Roh',
#    'age': 56,
#    'title': 'ActingHdofeviceeXperienceDivision, Pres, HdofMobileeXperience, CEOofSmart Phone Div & Exec Director',
#    'yearBorn': 1968,
#    'fiscalYear': 2024,
#    'totalPay': 5099000000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hark-Kyu  Park',
#    'age': 60,
#    'title': 'President & Head of Corporate Management Office at DX Division',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 3346000000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Si-young  Choi',
#    'title': 'President & Head of Foundry Business',
#    'fiscalYear': 2024,
#    'totalPay': 6900000000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Young-Hyun  Jun',
#    'age': 64,
#    'title': 'CEO, Head of the Device Solutions Division & Executive Director',
#    'yearBorn': 1960,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mauro  Porcini',
#    'title': 'President & Chief Design Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hyun-Chong  Kim',
#    'title': 'President and Chief Legal Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Kyungwhoon  Cheun',
#    'title': 'President',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Soon-Cheol  Park',
#    'age': 58,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1966,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robert M. Yi',
#    'title': 'Head of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jung-ho  Park',
#    'age': 53,
#    'title': 'Head of Compliance Team & Executive VP',
#    'yearBorn': 1971,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 1,
#  'boardRisk': 2,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 2,
#  'governanceEpochDate': 1746057600,
#  'compensationAsOfEpochDate': 1735603200,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 54700.0,
#  'open': 54200.0,
#  'dayLow': 53800.0,
#  'dayHigh': 54500.0,
#  'regularMarketPreviousClose': 54700.0,
#  'regularMarketOpen': 54200.0,
#  'regularMarketDayLow': 53800.0,
#  'regularMarketDayHigh': 54500.0,
#  'dividendRate': 1450.0,
#  'dividendYield': 2.65,
#  'exDividendDate': 1743120000,
#  'payoutRatio': 0.28059998,
#  'fiveYearAvgDividendYield': 2.58,
#  'beta': 0.744,
#  'volume': 13348405,
#  'regularMarketVolume': 13348405,
#  'averageVolume': 16569467,
#  'averageVolume10days': 11691557,
#  'averageDailyVolume10Day': 11691557,
#  'bid': 53900.0,
#  'ask': 54000.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 355089441095680,
#  'fiftyTwoWeekLow': 49900.0,
#  'fiftyTwoWeekHigh': 88800.0,
#  'priceToSalesTrailing12Months': 1.1525292,
#  'fiftyDayAverage': 56480.0,
#  'twoHundredDayAverage': 58633.5,
#  'currency': 'KRW',
#  'tradeable': False,
#  'enterpriseValue': 280565383168000,
#  'forwardPE': 8.982416,
#  'profitMargins': 0.113690004,
#  'floatShares': 5472191236,
#  'sharesOutstanding': 5919640064,
#  'heldPercentInsiders': 0.10067,
#  'heldPercentInstitutions': 0.47284,
#  'impliedSharesOutstanding': 6865650176,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1743379200,
#  'earningsQuarterlyGrowth': 0.213,
#  'netIncomeToCommon': 35028740341760,
#  'lastSplitFactor': '50:1',
#  'lastSplitDate': 1526428800,
#  'enterpriseToRevenue': 0.911,
#  'enterpriseToEbitda': 3.702,
#  '52WeekChange': -0.29510307,
#  'SandP52WeekChange': 0.09362543,
#  'lastDividendValue': 365.0,
#  'lastDividendDate': 1743120000,
#  'quoteType': 'EQUITY',
#  'currentPrice': 53900.0,
#  'targetHighPrice': 88000.0,
#  'targetLowPrice': 48000.0,
#  'targetMeanPrice': 72942.2,
#  'targetMedianPrice': 74000.0,
#  'recommendationMean': 1.62857,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 34,
#  'totalCash': 105133560037376,
#  'totalCashPerShare': 15807.524,
#  'ebitda': 75787625562112,
#  'totalDebt': 11143948009472,
#  'quickRatio': 1.763,
#  'currentRatio': 2.467,
#  'totalRevenue': 308095821545472,
#  'debtToEquity': 2.741,
#  'revenuePerShare': 45452.383,
#  'returnOnAssets': 0.04153,
#  'returnOnEquity': 0.09228,
#  'grossProfits': 116409937952768,
#  'freeCashflow': 17463475437568,
#  'operatingCashflow': 77697183121408,
#  'earningsGrowth': -0.999,
#  'revenueGrowth': 0.1,
#  'grossMargins': 0.37784,
#  'ebitdaMargins': 0.24599001,
#  'operatingMargins': 0.08447,
#  'financialCurrency': 'KRW',
#  'symbol': '005930.KS',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'fullExchangeName': 'KSE',
#  'averageDailyVolume3Month': 16569467,
#  'fiftyTwoWeekLowChange': 4000.0,
#  'fiftyTwoWeekLowChangePercent': 0.08016032,
#  'fiftyTwoWeekRange': '49900.0 - 88800.0',
#  'fiftyTwoWeekHighChange': -34900.0,
#  'fiftyTwoWeekHighChangePercent': -0.393018,
#  'fiftyTwoWeekChangePercent': -29.510307,
#  'earningsTimestamp': 1746010740,
#  'earningsTimestampStart': 1753786740,
#  'earningsTimestampEnd': 1754308800,
#  'earningsCallTimestampStart': 1745974800,
#  'earningsCallTimestampEnd': 1745974800,
#  'isEarningsDateEstimate': True,
#  'epsCurrentYear': 4918.227,
#  'priceEpsCurrentYear': 10.959234,
#  'fiftyDayAverageChange': -2580.0,
#  'fiftyDayAverageChangePercent': -0.045679886,
#  'twoHundredDayAverageChange': -4733.5,
#  'twoHundredDayAverageChangePercent': -0.0807303,
#  'sourceInterval': 20,
#  'exchangeDataDelayedBy': 20,
#  'averageAnalystRating': '1.6 - Buy',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 946944000000,
#  'regularMarketChange': -800.0,
#  'regularMarketDayRange': '53800.0 - 54500.0',
#  'corporateActions': [],
#  'regularMarketTime': 1748327425,
#  'exchange': 'KSC',
#  'messageBoardId': 'finmb_91868',
#  'exchangeTimezoneName': 'Asia/Seoul',
#  'exchangeTimezoneShortName': 'KST',
#  'gmtOffSetMilliseconds': 32400000,
#  'market': 'kr_market',
#  'esgPopulated': False,
#  'shortName': 'SamsungElec',
#  'longName': 'Samsung Electronics Co., Ltd.',
#  'regularMarketChangePercent': -1.4625229,
#  'regularMarketPrice': 53900.0,
#  'marketState': 'POST',
#  'trailingPegRatio': 1.3687}

# %%
# 기본정보를 dict로 생성
basic_info = {
    "회사명" : company.info.get("longName", "정보 없음"),
    "산업": company.info.get("industry", "정보 없음"),
    "부문": company.info.get("sector", "정보 없음"),
    "시가총액": company.info.get("marketCap", "정보 없음"),
    "총 발행 주식": company.info.get("sharesOutstanding", "정보 없음"),
    "본사위치": company.info.get("address1", "정보 없음"),
    "웹사이트": company.info.get("website", "정보 없음"),
}

# %%
# 재무재표표
income_statement = company.financials
income_statement
# Out:
#                                                             2024-12-31  \
# Tax Effect Of Unusual Items                           -7643351884.3752
# Tax Rate For Calcs                                            0.082025
# Normalized EBITDA                                     81157657000000.0
# Total Unusual Items                                     -93183000000.0
# Total Unusual Items Excluding Goodwill                  -93183000000.0
# Net Income From Continuing Operation Net Minori...    33621363000000.0
# Reconciled Depreciation                               42630822000000.0
# Reconciled Cost Of Revenue                           186562268000000.0
# EBITDA                                                81064474000000.0
# EBIT                                                  38433652000000.0
# Net Interest Income                                    3915210000000.0
# Interest Expense                                        903918000000.0
# Interest Income                                        4819128000000.0
# Normalized Income                                   33706902648115.625
# Net Income From Continuing And Discontinued Ope...    33621363000000.0
# Total Expenses                                       268144942000000.0
# Total Operating Income As Reported                    32725961000000.0
# Diluted Average Shares                                    6792194545.0
# Basic Average Shares                                      6792194545.0
# Diluted EPS                                                     4950.0
# Basic EPS                                                       4950.0
# Diluted NI Availto Com Stockholders                                NaN
# Net Income Common Stockholders                        33621363000000.0
# Otherunder Preferred Stock Dividend                                NaN
# Preferred Stock Dividends                                          NaN
# Net Income                                            33621363000000.0
# Minority Interests                                     -829988000000.0
# Net Income Including Noncontrolling Interests         34451351000000.0
# Net Income Continuous Operations                      34451351000000.0
# Tax Provision                                          3078383000000.0
# Pretax Income                                         37529734000000.0
# Other Non Operating Income Expenses                     458747000000.0
# Special Income Charges                                 -258590000000.0
# Other Special Charges                                   258590000000.0
# Net Non Operating Interest Income Expense              3915210000000.0
# Interest Expense Non Operating                          903918000000.0
# Interest Income Non Operating                          4819128000000.0
# Operating Income                                      32725961000000.0
# Operating Expense                                     81582674000000.0
# Depreciation And Amortization In Income Statement      2405725000000.0
# Amortization                                            716646000000.0
# Depreciation Income Statement                          1689079000000.0
# Research And Development                              34998142000000.0
# Selling General And Administration                    35078235000000.0
# Selling And Marketing Expense                         28340823000000.0
# General And Administrative Expense                     6737412000000.0
# Gross Profit                                         114308635000000.0
# Cost Of Revenue                                      186562268000000.0
# Total Revenue                                        300870903000000.0
# Operating Revenue                                    300870903000000.0
#
#                                                            2023-12-31  \
# Tax Effect Of Unusual Items                            -22864080000.0
# Tax Rate For Calcs                                               0.24
# Normalized EBITDA                                    50698344000000.0
# Total Unusual Items                                    -95267000000.0
# Total Unusual Items Excluding Goodwill                 -95267000000.0
# Net Income From Continuing Operation Net Minori...   14473401000000.0
# Reconciled Depreciation                              38666559000000.0
# Reconciled Cost Of Revenue                          180388580000000.0
# EBITDA                                               50603077000000.0
# EBIT                                                 11936518000000.0
# Net Interest Income                                   3427769000000.0
# Interest Expense                                       930253000000.0
# Interest Income                                       4358022000000.0
# Normalized Income                                    14545803920000.0
# Net Income From Continuing And Discontinued Ope...   14473401000000.0
# Total Expenses                                      252368518000000.0
# Total Operating Income As Reported                    6566976000000.0
# Diluted Average Shares                                   6791835289.0
# Basic Average Shares                                     6791835289.0
# Diluted EPS                                                    2131.0
# Basic EPS                                                      2131.0
# Diluted NI Availto Com Stockholders                               NaN
# Net Income Common Stockholders                       14473401000000.0
# Otherunder Preferred Stock Dividend                               NaN
# Preferred Stock Dividends                                         NaN
# Net Income                                           14473401000000.0
# Minority Interests                                   -1013699000000.0
# Net Income Including Noncontrolling Interests        15487100000000.0
# Net Income Continuous Operations                     15487100000000.0
# Tax Provision                                        -4480835000000.0
# Pretax Income                                        11006265000000.0
# Other Non Operating Income Expenses                    157431000000.0
# Special Income Charges                                -224513000000.0
# Other Special Charges                                  224513000000.0
# Net Non Operating Interest Income Expense             3427769000000.0
# Interest Expense Non Operating                         930253000000.0
# Interest Income Non Operating                         4358022000000.0
# Operating Income                                      6566976000000.0
# Operating Expense                                    71979938000000.0
# Depreciation And Amortization In Income Statement     2338121000000.0
# Amortization                                           688786000000.0
# Depreciation Income Statement                         1649335000000.0
# Research And Development                             28339724000000.0
# Selling General And Administration                   32678162000000.0
# Selling And Marketing Expense                        26552163000000.0
# General And Administrative Expense                    6125999000000.0
# Gross Profit                                         78546914000000.0
# Cost Of Revenue                                     180388580000000.0
# Total Revenue                                       258935494000000.0
# Operating Revenue                                   258935494000000.0
#
#                                                            2022-12-31  \
# Tax Effect Of Unusual Items                            -25405600000.0
# Tax Rate For Calcs                                              0.275
# Normalized EBITDA                                    86403532000000.0
# Total Unusual Items                                    -92384000000.0
# Total Unusual Items Excluding Goodwill                 -92384000000.0
# Net Income From Continuing Operation Net Minori...   54730018000000.0
# Reconciled Depreciation                              39107659000000.0
# Reconciled Cost Of Revenue                          190041770000000.0
# EBITDA                                               86311148000000.0
# EBIT                                                 47203489000000.0
# Net Interest Income                                   1957464000000.0
# Interest Expense                                       763015000000.0
# Interest Income                                       2720479000000.0
# Normalized Income                                    54796996400000.0
# Net Income From Continuing And Discontinued Ope...   54730018000000.0
# Total Expenses                                      258854730000000.0
# Total Operating Income As Reported                   43376630000000.0
# Diluted Average Shares                                   6792853171.0
# Basic Average Shares                                     6792853171.0
# Diluted EPS                                                    8057.0
# Basic EPS                                                      8057.0
# Diluted NI Availto Com Stockholders                               NaN
# Net Income Common Stockholders                       54730018000000.0
# Otherunder Preferred Stock Dividend                               NaN
# Preferred Stock Dividends                                         NaN
# Net Income                                           54730018000000.0
# Minority Interests                                    -924059000000.0
# Net Income Including Noncontrolling Interests        55654077000000.0
# Net Income Continuous Operations                     55654077000000.0
# Tax Provision                                        -9213603000000.0
# Pretax Income                                        46440474000000.0
# Other Non Operating Income Expenses                    -34632000000.0
# Special Income Charges                                -208074000000.0
# Other Special Charges                                  208074000000.0
# Net Non Operating Interest Income Expense             1957464000000.0
# Interest Expense Non Operating                         763015000000.0
# Interest Income Non Operating                         2720479000000.0
# Operating Income                                     43376630000000.0
# Operating Expense                                    68812960000000.0
# Depreciation And Amortization In Income Statement     2239103000000.0
# Amortization                                           664346000000.0
# Depreciation Income Statement                         1574757000000.0
# Research And Development                             24919198000000.0
# Selling General And Administration                   33560956000000.0
# Selling And Marketing Expense                        27567710000000.0
# General And Administrative Expense                    5993246000000.0
# Gross Profit                                        112189590000000.0
# Cost Of Revenue                                     190041770000000.0
# Total Revenue                                       302231360000000.0
# Operating Revenue                                   302231360000000.0
#
#                                                             2021-12-31  \
# Tax Effect Of Unusual Items                        -13557566210.000643
# Tax Rate For Calcs                                            0.251995
# Normalized EBITDA                                     88084529000000.0
# Total Unusual Items                                     -53801000000.0
# Total Unusual Items Excluding Goodwill                  -53801000000.0
# Net Income From Continuing Operation Net Minori...    39243791000000.0
# Reconciled Depreciation                               34247361000000.0
# Reconciled Cost Of Revenue                           166411342000000.0
# EBITDA                                                88030728000000.0
# EBIT                                                  53783367000000.0
# Net Interest Income                                     846738000000.0
# Interest Expense                                        431540000000.0
# Interest Income                                        1278278000000.0
# Normalized Income                                     39284034433790.0
# Net Income From Continuing And Discontinued Ope...    39243791000000.0
# Total Expenses                                       227970943000000.0
# Total Operating Income As Reported                    51633856000000.0
# Diluted Average Shares                                    6793109053.0
# Basic Average Shares                                      6793109053.0
# Diluted EPS                                                     5777.0
# Basic EPS                                                       5777.0
# Diluted NI Availto Com Stockholders                                NaN
# Net Income Common Stockholders                        39243791000000.0
# Otherunder Preferred Stock Dividend                                NaN
# Preferred Stock Dividends                                          NaN
# Net Income                                            39243791000000.0
# Minority Interests                                     -663659000000.0
# Net Income Including Noncontrolling Interests         39907450000000.0
# Net Income Continuous Operations                      39907450000000.0
# Tax Provision                                         13444377000000.0
# Pretax Income                                         53351827000000.0
# Other Non Operating Income Expenses                      19997000000.0
# Special Income Charges                                   -6113000000.0
# Other Special Charges                                     6113000000.0
# Net Non Operating Interest Income Expense               846738000000.0
# Interest Expense Non Operating                          431540000000.0
# Interest Income Non Operating                          1278278000000.0
# Operating Income                                      51633856000000.0
# Operating Expense                                     61559601000000.0
# Depreciation And Amortization In Income Statement      2073051000000.0
# Amortization                                            543544000000.0
# Depreciation Income Statement                          1529507000000.0
# Research And Development                              22401726000000.0
# Selling General And Administration                    29528020000000.0
# Selling And Marketing Expense                         24687074000000.0
# General And Administrative Expense                     4840946000000.0
# Gross Profit                                         113193457000000.0
# Cost Of Revenue                                      166411342000000.0
# Total Revenue                                        279604799000000.0
# Operating Revenue                                    279604799000000.0
#
#                                                           2020-12-31
# Tax Effect Of Unusual Items                                      NaN
# Tax Rate For Calcs                                               NaN
# Normalized EBITDA                                                NaN
# Total Unusual Items                                              NaN
# Total Unusual Items Excluding Goodwill                           NaN
# Net Income From Continuing Operation Net Minori...               NaN
# Reconciled Depreciation                                          NaN
# Reconciled Cost Of Revenue                                       NaN
# EBITDA                                                           NaN
# EBIT                                                             NaN
# Net Interest Income                                              NaN
# Interest Expense                                                 NaN
# Interest Income                                                  NaN
# Normalized Income                                                NaN
# Net Income From Continuing And Discontinued Ope...               NaN
# Total Expenses                                                   NaN
# Total Operating Income As Reported                               NaN
# Diluted Average Shares                                           NaN
# Basic Average Shares                                             NaN
# Diluted EPS                                                      NaN
# Basic EPS                                                        NaN
# Diluted NI Availto Com Stockholders                 22929390000000.0
# Net Income Common Stockholders                                   NaN
# Otherunder Preferred Stock Dividend                              0.0
# Preferred Stock Dividends                            3161456000000.0
# Net Income                                                       NaN
# Minority Interests                                               NaN
# Net Income Including Noncontrolling Interests                    NaN
# Net Income Continuous Operations                                 NaN
# Tax Provision                                                    NaN
# Pretax Income                                                    NaN
# Other Non Operating Income Expenses                              NaN
# Special Income Charges                                           NaN
# Other Special Charges                                            NaN
# Net Non Operating Interest Income Expense                        NaN
# Interest Expense Non Operating                                   NaN
# Interest Income Non Operating                                    NaN
# Operating Income                                                 NaN
# Operating Expense                                                NaN
# Depreciation And Amortization In Income Statement                NaN
# Amortization                                                     NaN
# Depreciation Income Statement                                    NaN
# Research And Development                                         NaN
# Selling General And Administration                               NaN
# Selling And Marketing Expense                                    NaN
# General And Administrative Expense                               NaN
# Gross Profit                                                     NaN
# Cost Of Revenue                                                  NaN
# Total Revenue                                                    NaN
# Operating Revenue                                                NaN

# %%
# 재무상태표표
balance_sheet = company.balance_sheet
balance_sheet
# Out:
#                                                          2024-12-31  \
# Treasury Shares Number                                          NaN
# Preferred Shares Number                                 822886700.0
# Ordinary Shares Number                                 6792669250.0
# Share Issued                                           6792669250.0
# Total Debt                                         19330184000000.0
# ...                                                             ...
# Gross Accounts Receivable                          44044073000000.0
# Cash Cash Equivalents And Short Term Investments  112651790000000.0
# Other Short Term Investments                       58946211000000.0
# Cash And Cash Equivalents                          53705579000000.0
# Cash Equivalents                                   53705579000000.0
#
#                                                         2023-12-31  \
# Treasury Shares Number                                         0.0
# Preferred Shares Number                                822886700.0
# Ordinary Shares Number                                5969782550.0
# Share Issued                                          5969782550.0
# Total Debt                                        12685944000000.0
# ...                                                            ...
# Gross Accounts Receivable                         37002849000000.0
# Cash Cash Equivalents And Short Term Investments  92407210000000.0
# Other Short Term Investments                      23326317000000.0
# Cash And Cash Equivalents                         69080893000000.0
# Cash Equivalents                                  69080893000000.0
#
#                                                          2022-12-31  \
# Treasury Shares Number                                          0.0
# Preferred Shares Number                                 822886700.0
# Ordinary Shares Number                                 5969782550.0
# Share Issued                                           5969782550.0
# Total Debt                                         10333242000000.0
# ...                                                             ...
# Gross Accounts Receivable                          36033784000000.0
# Cash Cash Equivalents And Short Term Investments  115227286000000.0
# Other Short Term Investments                       65546576000000.0
# Cash And Cash Equivalents                          49680710000000.0
# Cash Equivalents                                   49680710000000.0
#
#                                                          2021-12-31 2020-12-31
# Treasury Shares Number                                          0.0        0.0
# Preferred Shares Number                                 822886700.0        NaN
# Ordinary Shares Number                                 5969782550.0        NaN
# Share Issued                                           5969782550.0        NaN
# Total Debt                                         18392149000000.0        NaN
# ...                                                             ...        ...
# Gross Accounts Receivable                          41024295000000.0        NaN
# Cash Cash Equivalents And Short Term Investments  124150192000000.0        NaN
# Other Short Term Investments                       85118777000000.0        NaN
# Cash And Cash Equivalents                          39031415000000.0        NaN
# Cash Equivalents                                   39031415000000.0        NaN
#
# [84 rows x 5 columns]

# %%
# 현금흐름표
cash_flow = company.cashflow
cash_flow
# Out:
#                                              2024-12-31        2023-12-31  \
# Free Cash Flow                         19240982000000.0 -16396740000000.0
# Repurchase Of Capital Stock            -1811775000000.0               NaN
# Repayment Of Debt                      -1364508000000.0  -1219579000000.0
# Issuance Of Debt                        6276300000000.0   2500112000000.0
# Capital Expenditure                   -53741639000000.0 -60534167000000.0
# ...                                                 ...               ...
# Depreciation                           39649982000000.0  35532411000000.0
# Pension And Employee Benefit Expense    1571338000000.0   1157422000000.0
# Gain Loss On Investment Securities      -134952000000.0   -164203000000.0
# Gain Loss On Sale Of PPE                  42371000000.0    -18864000000.0
# Net Income From Continuing Operations  34451351000000.0  15487100000000.0
#
#                                              2022-12-31        2021-12-31  \
# Free Cash Flow                          9054614000000.0  15276427000000.0
# Repurchase Of Capital Stock                         NaN               NaN
# Repayment Of Debt                      -9847614000000.0  -3511692000000.0
# Issuance Of Debt                         271997000000.0     58279000000.0
# Capital Expenditure                   -53126732000000.0 -49829021000000.0
# ...                                                 ...               ...
# Depreciation                           35952098000000.0  31285209000000.0
# Pension And Employee Benefit Expense    1440099000000.0   1360344000000.0
# Gain Loss On Investment Securities      -414601000000.0   -135840000000.0
# Gain Loss On Sale Of PPE                 -97867000000.0   -264814000000.0
# Net Income From Continuing Operations  55654077000000.0  39907450000000.0
#
#                                       2020-12-31
# Free Cash Flow                               NaN
# Repurchase Of Capital Stock                  NaN
# Repayment Of Debt                            NaN
# Issuance Of Debt                             NaN
# Capital Expenditure                          NaN
# ...                                          ...
# Depreciation                                 NaN
# Pension And Employee Benefit Expense         NaN
# Gain Loss On Investment Securities           NaN
# Gain Loss On Sale Of PPE                     NaN
# Net Income From Continuing Operations        NaN
#
# [61 rows x 5 columns]

# %%
# 주가 수익 비율
pe_ratio = company.info.get('forwardPE')
# 주가 순자산 비율
pb_ratio = company.info.get('priceToBook')
# 주당 순이익
eps = company.info.get('trailingEps')
# 자기 자본 이익률
roe = company.info.get('returnOnEquity')
# 현재 거래량
current_volume = company.info.get('volume')

# %%
import yfinance as yf
import pandas as pd

class Stock:
    def __init__(self, symbol):
        self.symbol = symbol
        self.ticker = yf.Ticker(symbol)

    def get_basic_info(self):
        basic_info = pd.DataFrame.from_dict(self.ticker.info, orient="index", columns=["Values"])
        return basic_info.loc[['longName', 'industry', 'sector', 'marketCap', 'sharesOutstanding']].to_markdown()

    def get_financial_statement(self):
        return f"""
        ### Quarterly Income Statement
        {self.ticker.quarterly_income_stmt.loc[['Total Revenue', 'Gross Profit', 'Operating Income', 'Net Income']].to_markdown()}

        ### Quarterly Balance Sheet
        {self.ticker.quarterly_balance_sheet.loc[['Total Assets', 'Total Liabilities Net Minority Interest', 'Stockholders Equity']].to_markdown()}

        ### Quarterly Cash Flow
        {self.ticker.quarterly_cash_flow.loc[['Operating Cash Flow', 'Investing Cash Flow', 'Financing Cash Flow']].to_markdown()}
        """

def main():
    if __name__ == "__main__":
        stock = Stock('005930.KS')
        
        print("\n### Basic Information")
        print(stock.get_basic_info())

        print("\n### Financial Statements")
        print(stock.get_financial_statement())

main()
# Out:
# ### Basic Information
# |                   | Values                        |
# |:------------------|:------------------------------|
# | longName          | Samsung Electronics Co., Ltd. |
# | industry          | Consumer Electronics          |
# | sector            | Technology                    |
# | marketCap         | 355089441095680               |
# | sharesOutstanding | 5919640064                    |
#
# ### Financial Statements
#
#         ### Quarterly Income Statement
#         |                  |   2025-03-31 00:00:00 |   2024-12-31 00:00:00 |   2024-09-30 00:00:00 |   2024-06-30 00:00:00 |   2024-03-31 00:00:00 |   2023-12-31 00:00:00 |   2023-09-30 00:00:00 |
# |:-----------------|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|
# | Total Revenue    |           7.91405e+13 |           7.57883e+13 |           7.90987e+13 |           7.40683e+13 |           7.19156e+13 |                   nan |                   nan |
# | Gross Profit     |           2.81306e+13 |           2.85194e+13 |           3.00036e+13 |           2.97563e+13 |           2.60293e+13 |                   nan |                   nan |
# | Operating Income |           2.81306e+13 |           6.4927e+12  |           9.18337e+12 |           1.04439e+13 |           6.60601e+12 |                   nan |                   nan |
# | Net Income       |           8.02841e+12 |           7.57613e+12 |           9.78155e+12 |           9.64265e+12 |           6.62103e+12 |                   nan |                   nan |
#
#         ### Quarterly Balance Sheet
#         |                                         |   2025-03-31 00:00:00 |   2024-12-31 00:00:00 |   2024-09-30 00:00:00 |   2024-06-30 00:00:00 |   2024-03-31 00:00:00 |   2023-12-31 00:00:00 |   2023-09-30 00:00:00 |
# |:----------------------------------------|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|
# | Total Assets                            |           5.16377e+14 |           5.14532e+14 |           4.91307e+14 |           4.85758e+14 |           4.709e+14   |                   nan |                   nan |
# | Total Liabilities Net Minority Interest |           1.09762e+14 |           1.1234e+14  |           1.05026e+14 |           1.02231e+14 |           9.89837e+13 |                   nan |                   nan |
# | Stockholders Equity                     |           3.95861e+14 |           3.91688e+14 |           3.76152e+14 |           3.7367e+14  |           3.62315e+14 |                   nan |                   nan |
#
#         ### Quarterly Cash Flow
#         |                     |   2024-12-31 00:00:00 |   2024-09-30 00:00:00 |   2024-06-30 00:00:00 |   2024-03-31 00:00:00 |   2023-12-31 00:00:00 |   2023-09-30 00:00:00 |
# |:--------------------|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|----------------------:|
# | Operating Cash Flow |           2.20223e+13 |           2.21986e+13 |           1.68954e+13 |           1.18663e+13 |           1.99452e+13 |                   nan |
# | Investing Cash Flow |          -1.18679e+13 |          -2.53828e+13 |          -2.61202e+13 |          -2.20108e+13 |          -2.45221e+13 |                   nan |
# | Financing Cash Flow |          -2.78108e+12 |          -2.17854e+12 |          -4.09928e+12 |           1.26166e+12 |           1.25378e+11 |                   nan |

# %%
from langchain.prompts import ChatPromptTemplate


prompt = ChatPromptTemplate.from_messages([
    ("system", """
        Want assistance provided by qualified individuals enabled with experience on understanding charts 
        using technical analysis tools while interpreting macroeconomic environment prevailing across world 
        consequently assisting customers acquire long term advantages requires clear verdicts therefore 
        seeking same through informed predictions written down precisely! First statement contains 
        following content- "Can you tell us what future stock market looks like based upon current conditions ?".
    """),
    ("user", """
        {company} 주식에 투자해도 될까요?
        아래의 기본정보, 재무제표를 참고해 마크다운 형식의 투자보고서를 한글로 작성해 주세요.

        기본정보:
        {basic_info}

        재무제표:
        {financial_statement}

     """)
])

# %%
from langchain_core.output_parsers import StrOutputParser
chain = prompt | llm | StrOutputParser()
company = "Nvidia"
symbol = "NVDA"
stock = Stock(symbol)
result = chain.invoke({
    "company": company,
    "basic_info": stock.get_basic_info(),
    "financial_statement": stock.get_financial_statement()
})
print(result)
# Out:
# # NVIDIA Corporation 투자 보고서
#
# ## 기본 정보
# | 항목                | 값                  |
# |:------------------|:-------------------|
# | 회사명            | NVIDIA Corporation  |
# | 산업              | 반도체             |
# | 섹터              | 기술               |
# | 시가총액          | 3,201,847,787,520  |
# | 발행주식수        | 24,387,600,384     |
#
# ## 재무제표 분석
#
# ### 분기별 손익계산서
# | 항목              | 2025-01-31 | 2024-10-31 | 2024-07-31 | 2024-04-30 | 2024-01-31 | 2023-10-31 |
# |:-----------------|------------:|------------:|------------:|------------:|------------:|------------:|
# | 총 수익          | 39,331,000,000 | 35,082,000,000 | 30,040,000,000 | 26,044,000,000 | 22,103,000,000 | -          |
# | 총 이익          | 28,723,000,000 | 26,156,000,000 | 22,574,000,000 | 20,406,000,000 | 16,791,000,000 | -          |
# | 운영 이익        | 24,034,000,000 | 21,869,000,000 | 18,642,000,000 | 16,909,000,000 | 13,614,000,000 | -          |
# | 순이익           | 22,091,000,000 | 19,309,000,000 | 16,599,000,000 | 14,881,000,000 | 12,285,000,000 | -          |
#
# ### 분기별 대차대조표
# | 항목                                   | 2025-01-31 | 2024-10-31 | 2024-07-31 | 2024-04-30 | 2024-01-31 | 2023-10-31 |
# |:--------------------------------------|------------:|------------:|------------:|------------:|------------:|------------:|
# | 총 자산                               | 111,601,000,000 | 96,013,000,000 | 85,227,000,000 | 77,072,000,000 | 65,728,000,000 | -          |
# | 총 부채 (소수지분 제외)              | 32,274,000,000  | 30,114,000,000 | 27,070,000,000 | 27,930,000,000 | 22,750,000,000 | -          |
# | 주주 자본                             | 79,327,000,000  | 65,899,000,000 | 58,157,000,000 | 49,142,000,000 | 42,978,000,000 | -          |
#
# ### 분기별 현금 흐름표
# | 항목                     | 2025-01-31 | 2024-10-31 | 2024-07-31 | 2024-04-30 | 2024-01-31 | 2023-10-31 |
# |:------------------------|------------:|------------:|------------:|------------:|------------:|------------:|
# | 운영 현금 흐름         | 16,629,000,000 | 17,627,000,000 | 14,488,000,000 | 15,345,000,000 | 11,499,000,000 | -          |
# | 투자 현금 흐름         | -7,198,000,000  | -4,346,000,000  | -3,184,000,000  | -5,693,000,000  | -6,109,000,000  | -          |
# | 재무 현금 흐름         | -9,949,000,000  | -12,745,000,000 | -10,320,000,000 | -9,345,000,000  | -3,629,000,000  | -          |
#
# ## 투자 결론
#
# NVIDIA Corporation은 반도체 산업에서 강력한 성장을 보여주고 있으며, 최근 분기 동안 총 수익과 순이익이 지속적으로 증가하고 있습니다. 특히, 2025년 1분기에는 총 수익이 39,331,000,000 달러에 달하며, 이는 이전 분기보다 상당한 증가를 나타냅니다.
#
# 또한, 총 자산과 주주 자본도 증가하고 있어 재무 건전성이 높아지고 있습니다. 운영 현금 흐름 또한 긍정적인 추세를 보이고 있지만, 투자 및 재무 현금 흐름은 부정적인 수치를 기록하고 있습니다. 이는 회사가 성장하기 위해 적극적으로 투자하고 있다는 것을 의미합니다.
#
# 종합적으로 볼 때, NVIDIA는 기술 혁신과 시장 수요에 힘입어 긍정적인 성장 전망을 가지고 있으며, 장기 투자에 적합한 기업으로 평가됩니다. 따라서, NVIDIA 주식에 대한 투자는 긍정적으로 고려할 수 있습니다.

# %%
with open(f"{company}_investment_report.md", "w", encoding="utf-8") as f:
    f.write(result)

# %%
import pandas as pd
df = pd.read_csv('nasdaq_screener.csv', na_filter=False)
df.head(100)
# Out:
#    Symbol                                               Name Last Sale  \
# 0       A             Agilent Technologies Inc. Common Stock   $108.53
# 1      AA                    Alcoa Corporation Common Stock     $28.07
# 2    AACB  Artius II Acquisition Inc. Class A Ordinary Sh...    $10.04
# 3   AACBR                  Artius II Acquisition Inc. Rights     $0.24
# 4   AACBU                   Artius II Acquisition Inc. Units    $10.24
# ..    ...                                                ...       ...
# 95   ADBE                            Adobe Inc. Common Stock   $407.69
# 96    ADC              Agree Realty Corporation Common Stock    $75.04
# 97  ADC^A  Agree Realty Corporation Depositary Shares eac...    $17.45
# 98   ADCT                  ADC Therapeutics SA Common Shares     $2.43
# 99    ADD  Color Star Technology Co. Ltd. Class A Ordinar...     $0.90
#
#     Net Change % Change       Market Cap        Country IPO Year   Volume  \
# 0      -1.1500  -1.049%   30942197876.00  United States     1999  1690973
# 1       0.0900   0.322%    7267388628.00  United States     2016  5294223
# 2       0.0000    0.00%             0.00  United States     2025    31050
# 3       0.0000    0.00%             0.00  United States     2025    50800
# 4      -0.0100  -0.098%             0.00  United States     2025      142
# ..         ...      ...              ...            ...      ...      ...
# 95     -6.6400  -1.603%  173920554000.00  United States     1986  2086798
# 96      0.5400   0.725%    8255791842.00  United States           1002913
# 97      0.0000    0.00%                   United States              8571
# 98      0.2000   8.969%     241003235.00    Switzerland     2020   940648
# 99      0.0173    1.96%        553173.00  United States            219674
#
#                     Sector                                          Industry
# 0              Industrials  Biotechnology: Laboratory Analytical Instruments
# 1              Industrials                                          Aluminum
# 2
# 3
# 4                  Finance                                      Blank Checks
# ..                     ...                                               ...
# 95              Technology           Computer Software: Prepackaged Software
# 96             Real Estate                     Real Estate Investment Trusts
# 97
# 98             Health Care        Biotechnology: Pharmaceutical Preparations
# 99  Consumer Discretionary                        Engineering & Construction
#
# [100 rows x 11 columns]

# %%
import pandas as pd
df = pd.read_csv('nasdaq_screener.csv', na_filter=False)
# df['id'] = df['Symbol'].str.strip().replace(r'\^','_', regex=True)
df['id'] = df['Symbol'].str.strip().replace(r'[/^]','_', regex=True)

# %%
result_d = df.to_dict(orient='records')
result_d[:5]
# Out:
# [{'Symbol': 'A',
#   'Name': 'Agilent Technologies Inc. Common Stock',
#   'Last Sale': '$108.53',
#   'Net Change': -1.15,
#   '% Change': '-1.049%',
#   'Market Cap': '30942197876.00',
#   'Country': 'United States',
#   'IPO Year': '1999',
#   'Volume': 1690973,
#   'Sector': 'Industrials',
#   'Industry': 'Biotechnology: Laboratory Analytical Instruments',
#   'id': 'A'},
#  {'Symbol': 'AA',
#   'Name': 'Alcoa Corporation Common Stock ',
#   'Last Sale': '$28.07',
#   'Net Change': 0.09,
#   '% Change': '0.322%',
#   'Market Cap': '7267388628.00',
#   'Country': 'United States',
#   'IPO Year': '2016',
#   'Volume': 5294223,
#   'Sector': 'Industrials',
#   'Industry': 'Aluminum',
#   'id': 'AA'},
#  {'Symbol': 'AACB',
#   'Name': 'Artius II Acquisition Inc. Class A Ordinary Shares',
#   'Last Sale': '$10.04',
#   'Net Change': 0.0,
#   '% Change': '0.00%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 31050,
#   'Sector': '',
#   'Industry': '',
#   'id': 'AACB'},
#  {'Symbol': 'AACBR',
#   'Name': 'Artius II Acquisition Inc. Rights',
#   'Last Sale': '$0.24',
#   'Net Change': 0.0,
#   '% Change': '0.00%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 50800,
#   'Sector': '',
#   'Industry': '',
#   'id': 'AACBR'},
#  {'Symbol': 'AACBU',
#   'Name': 'Artius II Acquisition Inc. Units',
#   'Last Sale': '$10.24',
#   'Net Change': -0.01,
#   '% Change': '-0.098%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 142,
#   'Sector': 'Finance',
#   'Industry': 'Blank Checks',
#   'id': 'AACBU'}]

# %%
# %pip install meilisearch
# Out:
# Collecting meilisearch
#   Downloading meilisearch-0.34.1-py3-none-any.whl.metadata (964 bytes)
# Requirement already satisfied: requests in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from meilisearch) (2.32.3)
# Collecting camel-converter[pydantic] (from meilisearch)
#   Downloading camel_converter-4.0.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from camel-converter[pydantic]->meilisearch) (2.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from pydantic>=2.0.0->camel-converter[pydantic]->meilisearch) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from pydantic>=2.0.0->camel-converter[pydantic]->meilisearch) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from pydantic>=2.0.0->camel-converter[pydantic]->meilisearch) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from requests->meilisearch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from requests->meilisearch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from requests->meilisearch) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\treze\miniconda3\envs\llm\lib\site-packages (from requests->meilisearch) (2025.4.26)
# Downloading meilisearch-0.34.1-py3-none-any.whl (24 kB)
# Downloading camel_converter-4.0.1-py3-none-any.whl (6.2 kB)
# Installing collected packages: camel-converter, meilisearch
#
#    -------------------- ------------------- 1/2 [meilisearch]
#    -------------------- ------------------- 1/2 [meilisearch]
#    ---------------------------------------- 2/2 [meilisearch]
#
# Successfully installed camel-converter-4.0.1 meilisearch-0.34.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import meilisearch

# %%
import os
client = meilisearch.Client(url = os.getenv('MEILI_SEARCH_URL'),
                            api_key = os.getenv('MEILI_SEARCH_KEY'))
client.index('nasdaq').add_documents(result_d, primary_key='id')
# Out:
# TaskInfo(task_uid=2, index_uid='nasdaq', status='enqueued', type='documentAdditionOrUpdate', enqueued_at=datetime.datetime(2025, 5, 27, 8, 37, 59, 472496))

# %%
client.index('nasdaq').search('nv')
# Out:
# {'hits': [{'id': 'NVA',
#    'Symbol': 'NVA',
#    'Name': 'Nova Minerals Limited American Depositary Shares',
#    'Last Sale': '$12.00',
#    'Net Change': -0.39,
#    '% Change': '-3.148%',
#    'Market Cap': '54387372.00',
#    'Country': 'Australia',
#    'IPO Year': '2024',
#    'Volume': 5877,
#    'Sector': 'Basic Materials',
#    'Industry': 'Precious Metals'},
#   {'id': 'NVAWW',
#    'Symbol': 'NVAWW',
#    'Name': 'Nova Minerals Limited Warrant',
#    'Last Sale': '$6.60',
#    'Net Change': 0.0,
#    '% Change': '0.00%',
#    'Market Cap': '1794783415.00',
#    'Country': 'Australia',
#    'IPO Year': '2024',
#    'Volume': 302,
#    'Sector': 'Basic Materials',
#    'Industry': 'Precious Metals'},
#   {'id': 'NVAX',
#    'Symbol': 'NVAX',
#    'Name': 'Novavax Inc. Common Stock',
#    'Last Sale': '$7.25',
#    'Net Change': -0.04,
#    '% Change': '-0.549%',
#    'Market Cap': '1174284951.00',
#    'Country': 'United States',
#    'IPO Year': '',
#    'Volume': 5575090,
#    'Sector': 'Health Care',
#    'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)'},
#   {'id': 'NVCR',
#    'Symbol': 'NVCR',
#    'Name': 'NovoCure Limited Ordinary Shares',
#    'Last Sale': '$18.54',
#    'Net Change': 0.43,
#    '% Change': '2.374%',
#    'Market Cap': '2066943654.00',
#    'Country': 'Jersey',
#    'IPO Year': '2015',
#    'Volume': 869910,
#    'Sector': 'Health Care',
#    'Industry': 'Medical/Dental Instruments'},
#   {'id': 'NVCT',
#    'Symbol': 'NVCT',
#    'Name': 'Nuvectis Pharma Inc. Common Stock',
#    'Last Sale': '$9.83',
#    'Net Change': -0.12,
#    '% Change': '-1.206%',
#    'Market Cap': '232327980.00',
#    'Country': 'United States',
#    'IPO Year': '2022',
#    'Volume': 83412,
#    'Sector': 'Health Care',
#    'Industry': 'Biotechnology: Pharmaceutical Preparations'},
#   {'id': 'NVDA',
#    'Symbol': 'NVDA',
#    'Name': 'NVIDIA Corporation Common Stock',
#    'Last Sale': '$131.29',
#    'Net Change': -1.54,
#    '% Change': '-1.159%',
#    'Market Cap': '3203476000000.00',
#    'Country': 'United States',
#    'IPO Year': '1999',
#    'Volume': 198355616,
#    'Sector': 'Technology',
#    'Industry': 'Semiconductors'},
#   {'id': 'NVEC',
#    'Symbol': 'NVEC',
#    'Name': 'NVE Corporation Common Stock',
#    'Last Sale': '$71.75',
#    'Net Change': -1.41,
#    '% Change': '-1.927%',
#    'Market Cap': '347066661.00',
#    'Country': 'United States',
#    'IPO Year': '',
#    'Volume': 26867,
#    'Sector': 'Technology',
#    'Industry': 'Semiconductors'},
#   {'id': 'NVEE',
#    'Symbol': 'NVEE',
#    'Name': 'NV5 Global Inc. Common Stock',
#    'Last Sale': '$22.14',
#    'Net Change': -0.02,
#    '% Change': '-0.09%',
#    'Market Cap': '1453420993.00',
#    'Country': 'United States',
#    'IPO Year': '2013',
#    'Volume': 444643,
#    'Sector': 'Consumer Discretionary',
#    'Industry': 'Other Consumer Services'},
#   {'id': 'NVFY',
#    'Symbol': 'NVFY',
#    'Name': 'Nova Lifestyle Inc. Common Stock',
#    'Last Sale': '$1.48',
#    'Net Change': -0.06,
#    '% Change': '-3.896%',
#    'Market Cap': '20289057.00',
#    'Country': 'United States',
#    'IPO Year': '',
#    'Volume': 16509,
#    'Sector': 'Consumer Discretionary',
#    'Industry': 'Home Furnishings'},
#   {'id': 'NVG',
#    'Symbol': 'NVG',
#    'Name': 'Nuveen AMT-Free Municipal Credit Income Fund ',
#    'Last Sale': '$11.79',
#    'Net Change': -0.07,
#    '% Change': '-0.59%',
#    'Market Cap': '0.00',
#    'Country': 'United States',
#    'IPO Year': '2002',
#    'Volume': 316821,
#    'Sector': 'Finance',
#    'Industry': 'Investment Managers'},
#   {'id': 'NVGS',
#    'Symbol': 'NVGS',
#    'Name': 'Navigator Holdings Ltd. Ordinary Shares (Marshall Islands)',
#    'Last Sale': '$13.99',
#    'Net Change': 0.3,
#    '% Change': '2.191%',
#    'Market Cap': '970873096.00',
#    'Country': 'Marshall Islands',
#    'IPO Year': '2013',
#    'Volume': 360268,
#    'Sector': 'Consumer Discretionary',
#    'Industry': 'Marine Transportation'},
#   {'id': 'NVMI',
#    'Symbol': 'NVMI',
#    'Name': 'Nova Ltd. Ordinary Shares',
#    'Last Sale': '$183.00',
#    'Net Change': -1.71,
#    '% Change': '-0.926%',
#    'Market Cap': '5358055353.00',
#    'Country': 'Israel',
#    'IPO Year': '2000',
#    'Volume': 122707,
#    'Sector': 'Technology',
#    'Industry': 'Electronic Components'},
#   {'id': 'NVNI',
#    'Symbol': 'NVNI',
#    'Name': 'Nvni Group Limited Ordinary Shares',
#    'Last Sale': '$0.404',
#    'Net Change': -0.0069,
#    '% Change': '-1.679%',
#    'Market Cap': '37273040.00',
#    'Country': 'Cayman Islands',
#    'IPO Year': '',
#    'Volume': 3448555,
#    'Sector': 'Technology',
#    'Industry': 'Computer Software: Prepackaged Software'},
#   {'id': 'NVNIW',
#    'Symbol': 'NVNIW',
#    'Name': 'Nvni Group Limited Warrants',
#    'Last Sale': '$0.0798',
#    'Net Change': 0.0297,
#    '% Change': '59.281%',
#    'Market Cap': '7362348.00',
#    'Country': 'Cayman Islands',
#    'IPO Year': '',
#    'Volume': 379,
#    'Sector': 'Technology',
#    'Industry': 'Computer Software: Prepackaged Software'},
#   {'id': 'NVNO',
#    'Symbol': 'NVNO',
#    'Name': 'enVVeno Medical Corporation Common Stock',
#    'Last Sale': '$3.35',
#    'Net Change': -0.07,
#    '% Change': '-2.047%',
#    'Market Cap': '58745600.00',
#    'Country': 'United States',
#    'IPO Year': '2018',
#    'Volume': 46949,
#    'Sector': 'Health Care',
#    'Industry': 'Medical/Dental Instruments'},
#   {'id': 'NVO',
#    'Symbol': 'NVO',
#    'Name': 'Novo Nordisk A/S Common Stock',
#    'Last Sale': '$67.35',
#    'Net Change': -0.82,
#    '% Change': '-1.203%',
#    'Market Cap': '300717750000.00',
#    'Country': 'Denmark',
#    'IPO Year': '',
#    'Volume': 6503713,
#    'Sector': 'Health Care',
#    'Industry': 'Biotechnology: Pharmaceutical Preparations'},
#   {'id': 'NVR',
#    'Symbol': 'NVR',
#    'Name': 'NVR Inc. Common Stock',
#    'Last Sale': '$7066.39',
#    'Net Change': -4.81,
#    '% Change': '-0.068%',
#    'Market Cap': '20660930140.00',
#    'Country': 'United States',
#    'IPO Year': '1998',
#    'Volume': 18613,
#    'Sector': 'Consumer Discretionary',
#    'Industry': 'Homebuilding'},
#   {'id': 'NVRI',
#    'Symbol': 'NVRI',
#    'Name': 'Enviri Corporation Common Stock',
#    'Last Sale': '$7.54',
#    'Net Change': -0.12,
#    '% Change': '-1.567%',
#    'Market Cap': '606949491.00',
#    'Country': 'United States',
#    'IPO Year': '',
#    'Volume': 883143,
#    'Sector': 'Miscellaneous',
#    'Industry': 'Diversified Commercial Services'},
#   {'id': 'NVS',
#    'Symbol': 'NVS',
#    'Name': 'Novartis AG Common Stock',
#    'Last Sale': '$112.75',
#    'Net Change': 0.25,
#    '% Change': '0.222%',
#    'Market Cap': '222691312712.00',
#    'Country': 'Switzerland',
#    'IPO Year': '',
#    'Volume': 898860,
#    'Sector': 'Health Care',
#    'Industry': 'Biotechnology: Pharmaceutical Preparations'},
#   {'id': 'NVST',
#    'Symbol': 'NVST',
#    'Name': 'Envista Holdings Corporation Common Stock',
#    'Last Sale': '$16.72',
#    'Net Change': -0.15,
#    '% Change': '-0.889%',
#    'Market Cap': '2833822857.00',
#    'Country': 'United States',
#    'IPO Year': '2019',
#    'Volume': 2062553,
#    'Sector': 'Health Care',
#    'Industry': 'Medical/Dental Instruments'}],
#  'query': 'nv',
#  'processingTimeMs': 0,
#  'limit': 20,
#  'offset': 0,
#  'estimatedTotalHits': 72}
